# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
model = tf.keras.Sequential([tf.keras.layers.Embedding(10, 4)])

x = tf.random.uniform([1, 8], 0, 10, dtype=tf.int32)
print(x.shape)
plt.imshow(x)
plt.show()

y = model(x)
print(y.shape)
plt.imshow(y[0])
plt.show()
# Out:
# (1, 8)
# (1, 8, 4)
